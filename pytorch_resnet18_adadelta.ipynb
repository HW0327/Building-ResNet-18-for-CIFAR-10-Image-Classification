# %%
# %conda update -n base conda
# %conda install pytorch
# %conda install torchvision
# %pip install torch-summary
# %pip install matplotlib
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - conda
#
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   libnsl             conda-forge/linux-64::libnsl-2.0.0-h7f98852_0
#   libsqlite          conda-forge/linux-64::libsqlite-3.40.0-h753d276_0
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h7f98852_1000
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-h166bdaf_4
#   toolz              conda-forge/noarch::toolz-0.12.0-pyhd8ed1ab_0
#
# The following packages will be REMOVED:
#
#   chardet-4.0.0-py39hf3d152e_1
#   libstdcxx-ng-11.2.0-he4da1e4_9
#   six-1.16.0-pyh6c4a22f_0
#   zlib-1.2.11-h516909a_1010
#
# The following packages will be UPDATED:
#
#   _openmp_mutex                                   4.5-1_gnu --> 4.5-2_gnu
#   brotlipy                          0.7.0-py39h3811e60_1001 --> 0.7.0-py39hb9d737c_1005
#   ca-certificates                      2021.5.30-ha878542_0 --> 2022.9.24-ha878542_0
#   certifi            conda-forge/linux-64::certifi-2021.5.~ --> conda-forge/noarch::certifi-2022.9.24-pyhd8ed1ab_0
#   cffi                                1.14.6-py39h4bc2ebd_1 --> 1.15.1-py39he91dace_2
#   charset-normalizer                     2.0.0-pyhd8ed1ab_0 --> 2.1.1-pyhd8ed1ab_0
#   colorama                               0.4.4-pyh9f0ad1d_0 --> 0.4.6-pyhd8ed1ab_0
#   conda                               4.10.3-py39hf3d152e_2 --> 22.9.0-py39hf3d152e_2
#   conda-package-han~                   1.7.3-py39h3811e60_0 --> 1.9.0-py39hb9d737c_1
#   cryptography                         3.4.7-py39hbca0aa6_0 --> 38.0.3-py39h3ccb8fc_0
#   idna                                     3.1-pyhd3deb0d_0 --> 3.4-pyhd8ed1ab_0
#   ld_impl_linux-64                        2.36.1-hea4e1c9_2 --> 2.39-hcc3a1bd_1
#   libffi                                   3.4.2-h9c3ff4c_4 --> 3.4.2-h7f98852_5
#   libgcc-ng                               11.2.0-h1d223b6_9 --> 12.2.0-h65d4601_19
#   libgomp                                 11.2.0-h1d223b6_9 --> 12.2.0-h65d4601_19
#   ncurses                                    6.2-h58526e2_4 --> 6.3-h27087fc_1
#   openssl                                 1.1.1l-h7f98852_0 --> 3.0.7-h166bdaf_0
#   pycosat                           0.6.3-py39h3811e60_1006 --> 0.6.4-py39hb9d737c_1
#   pycparser                               2.20-pyh9f0ad1d_2 --> 2.21-pyhd8ed1ab_0
#   pyopenssl                             20.0.1-pyhd8ed1ab_0 --> 22.1.0-pyhd8ed1ab_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-p~ --> conda-forge/noarch::pysocks-1.7.1-pyha2e5f31_6
#   python                           3.9.7-hb7a2778_2_cpython --> 3.9.13-h2660328_0_cpython
#   readline                                   8.1-h46c0cb4_0 --> 8.1.2-h0f457ee_0
#   requests                              2.26.0-pyhd8ed1ab_0 --> 2.28.1-pyhd8ed1ab_1
#   ruamel_yaml                     0.15.80-py39h3811e60_1004 --> 0.15.80-py39hb9d737c_1008
#   setuptools         conda-forge/linux-64::setuptools-58.0~ --> conda-forge/noarch::setuptools-65.5.1-pyhd8ed1ab_0
#   sqlite                                  3.36.0-h9cd32fc_2 --> 3.40.0-h4ff8645_0
#   tk                                      8.6.11-h27826a3_1 --> 8.6.12-h27826a3_0
#   tqdm                                  4.62.3-pyhd8ed1ab_0 --> 4.64.1-pyhd8ed1ab_0
#   tzdata                                   2021a-he74cb21_1 --> 2022f-h191b570_0
#   urllib3                               1.26.7-pyhd8ed1ab_0 --> 1.26.11-pyhd8ed1ab_0
#   wheel                                 0.37.0-pyhd8ed1ab_1 --> 0.38.4-pyhd8ed1ab_0
#   xz                                       5.2.5-h516909a_1 --> 5.2.6-h166bdaf_0
#   yaml                                     0.2.5-h516909a_0 --> 0.2.5-h7f98852_2
#
#
# Preparing transaction: done
# Verifying transaction: failed
#
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: /opt/conda
#   uid: 1000
#   gid: 100
#
#
#
# Note: you may need to restart the kernel to use updated packages.
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch-summary in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (1.4.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (3.6.2)
# Requirement already satisfied: cycler>=0.10 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: numpy>=1.19 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms

import torchsummary
import matplotlib.pyplot as plt
import os
import sys
import time
import math

# %%
def get_mean_and_std(dataset):
    '''Compute the mean and std value of dataset.'''
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=1, shuffle=True, num_workers=2)
    mean = torch.zeros(3)
    std = torch.zeros(3)
    print('==> Computing mean and std..')
    for inputs, targets in dataloader:
        for i in range(3):
            mean[i] += inputs[:,i,:,:].mean()
            std[i] += inputs[:,i,:,:].std()
    mean.div_(len(dataset))
    std.div_(len(dataset))
    return mean, std


def init_params(net):
    '''Init layer parameters.'''
    for m in net.modules():
        if isinstance(m, nn.Conv2d):
            init.kaiming_normal(m.weight, mode='fan_out')
            if m.bias:
                init.constant(m.bias, 0)
        elif isinstance(m, nn.BatchNorm2d):
            init.constant(m.weight, 1)
            init.constant(m.bias, 0)
        elif isinstance(m, nn.Linear):
            init.normal(m.weight, std=1e-3)
            if m.bias:
                init.constant(m.bias, 0)


# _, term_width = os.popen('stty size', 'r').read().split()
term_width = 50

TOTAL_BAR_LENGTH = 65.
last_time = time.time()
begin_time = last_time


def progress_bar(current, total, msg=None):
    global last_time, begin_time
    if current == 0:
        begin_time = time.time()  # Reset for new bar.

    cur_len = int(TOTAL_BAR_LENGTH*current/total)
    rest_len = int(TOTAL_BAR_LENGTH - cur_len) - 1

    sys.stdout.write(' [')
    for i in range(cur_len):
        sys.stdout.write('=')
    sys.stdout.write('>')
    for i in range(rest_len):
        sys.stdout.write('.')
    sys.stdout.write(']')

    cur_time = time.time()
    step_time = cur_time - last_time
    last_time = cur_time
    tot_time = cur_time - begin_time

    L = []
    L.append('  Step: %s' % format_time(step_time))
    L.append(' | Tot: %s' % format_time(tot_time))
    if msg:
        L.append(' | ' + msg)

    msg = ''.join(L)
    sys.stdout.write(msg)
    for i in range(term_width-int(TOTAL_BAR_LENGTH)-len(msg)-3):
        sys.stdout.write(' ')

    # Go back to the center of the bar.
    for i in range(term_width-int(TOTAL_BAR_LENGTH/2)+2):
        sys.stdout.write('\b')
    sys.stdout.write(' %d/%d ' % (current+1, total))

    if current < total-1:
        sys.stdout.write('\r')
    else:
        sys.stdout.write('\n')
    sys.stdout.flush()


def format_time(seconds):
    days = int(seconds / 3600/24)
    seconds = seconds - days*3600*24
    hours = int(seconds / 3600)
    seconds = seconds - hours*3600
    minutes = int(seconds / 60)
    seconds = seconds - minutes*60
    secondsf = int(seconds)
    seconds = seconds - secondsf
    millis = int(seconds*1000)

    f = ''
    i = 1
    if days > 0:
        f += str(days) + 'D'
        i += 1
    if hours > 0 and i <= 2:
        f += str(hours) + 'h'
        i += 1
    if minutes > 0 and i <= 2:
        f += str(minutes) + 'm'
        i += 1
    if secondsf > 0 and i <= 2:
        f += str(secondsf) + 's'
        i += 1
    if millis > 0 and i <= 2:
        f += str(millis) + 'ms'
        i += 1
    if f == '':
        f = '0ms'
    return f

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 32

        self.conv1 = nn.Conv2d(3, 32, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.layer1 = self._make_layer(block, 32, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 64, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 256, num_blocks[3], stride=2)
        self.dropout = nn.Dropout(p=0.2)
        self.linear = nn.Linear(256*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.dropout(out)
        out = self.linear(out)
        return out

# %%
def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])


def ResNet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])


def ResNet101():
    return ResNet(Bottleneck, [3, 4, 23, 3])


def ResNet152():
    return ResNet(Bottleneck, [3, 8, 36, 3])

# %%
# parser = argparse.ArgumentParser(description='PyTorch CIFAR10 Training')
# parser.add_argument('--lr', default=0.1, type=float, help='learning rate')
# parser.add_argument('--resume', '-r', action='store_true',
#                     help='resume from checkpoint')
# args = parser.parse_args()

device = 'cuda' if torch.cuda.is_available() else 'cpu'
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch
Learning_rate = 0.0001
Resume = False
Optimizer = 'adadelta'  # sgd, sgdn, adagrad, adadelta or adam
Batch_size = 128


# Data
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=Batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=100, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# Model
print('==> Building model..')
net = ResNet18()
net = net.to(device)
if device == 'cuda':
    net = torch.nn.DataParallel(net)
    cudnn.benchmark = True

if Resume:
    # Load checkpoint.
    print('==> Resuming from checkpoint..')
    assert os.path.isdir('checkpoint'), 'Error: no checkpoint directory found!'
    checkpoint = torch.load('./checkpoint/ckpt.pth')
    net.load_state_dict(checkpoint['net'])
    best_acc = checkpoint['acc']
    start_epoch = checkpoint['epoch']

criterion = nn.CrossEntropyLoss(reduction='sum')
optimizer = optim.SGD(net.parameters(), lr=Learning_rate,
                      momentum=0.9, weight_decay=5e-4)
if Optimizer == 'sgdn':
    optimizer = optim.SGD(net.parameters(), lr=Learning_rate,
                    momentum=0.9, weight_decay=5e-4, nesterov=True)
elif Optimizer == 'adagrad':
    optimizer = optim.Adagrad(net.parameters(), lr=Learning_rate,
                              weight_decay=5e-4)
elif Optimizer == 'adadelta':
    optimizer = optim.Adadelta(net.parameters(), lr=Learning_rate,
                               weight_decay=5e-4)
elif Optimizer == 'adam':
    optimizer = optim.Adam(net.parameters(), lr=Learning_rate,
                           weight_decay=5e-4)
# scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)

torchsummary.summary(net, (3, 32, 32))


# Training
def train(epoch):
    print('\nEpoch: %d' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    total_training_time = 0
    time1 = torch.cuda.Event(enable_timing=True)
    time2 = torch.cuda.Event(enable_timing=True)
    time1.record()
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        time2.record()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        torch.cuda.synchronize()
        
        total_training_time += time1.elapsed_time(time2)
        
    avg_loss = train_loss/total
    acc = 100.*correct/total
    print('Training epoch %d: Loss=%.3f Acc=%.3f' %
          (epoch, avg_loss, acc))
    return avg_loss, acc


def test(epoch):
    global best_acc
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
        
    avg_loss = test_loss/total
    acc = 100.*correct/total
    print('Testing epoch %d: Loss=%.3f Acc=%.3f' %
          (epoch, avg_loss, acc))

    # Save checkpoint.
    acc = 100.*correct/total
    if acc > best_acc:
        print('Saving..')
        state = {
            'net': net.state_dict(),
            'acc': acc,
            'epoch': epoch,
        }
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        torch.save(state, './checkpoint/ckpt.pth')
        best_acc = acc
        
    return avg_loss, acc


filename = Optimizer + '_' + str(Batch_size) + '_' + str(Learning_rate) + '_dropout.csv'
file = open(filename, 'w')
file.write('train_avg_loss, train_acc, test_avg_loss, test_acc, train_time, test_time\n')
Start_time = time.perf_counter()
train_acc_history = []
test_acc_history = []
for epoch in range(start_epoch, start_epoch+120):
    time1 = time.perf_counter()
    train_avg_loss, train_acc = train(epoch)
    time2 = time.perf_counter()
    test_avg_loss, test_acc = test(epoch)
    Cur_time = time.perf_counter()
    # scheduler.step()
    train_acc_history.append(train_acc)
    test_acc_history.append(test_acc)
    print('Epoch %d: %.2fs' % (epoch, Cur_time - Start_time))
    print('Train: %.2fs, Test: %.2fs' % (time2 - time1, Cur_time - time2))
    file.write('%.3f, %.3f, %.3f, %.3f, %.2f, %.2f\n' %
               (train_avg_loss, train_acc, test_avg_loss, test_acc,
                time2 - time1, Cur_time - time2))
file.close()
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─ResNet: 1-1                            [-1, 10]                  --
# |    └─Conv2d: 2-1                       [-1, 32, 32, 32]          864
# |    └─BatchNorm2d: 2-2                  [-1, 32, 32, 32]          64
# |    └─Sequential: 2-3                   [-1, 32, 32, 32]          --
# |    |    └─BasicBlock: 3-1              [-1, 32, 32, 32]          18,560
# |    |    └─BasicBlock: 3-2              [-1, 32, 32, 32]          18,560
# |    └─Sequential: 2-4                   [-1, 64, 16, 16]          --
# |    |    └─BasicBlock: 3-3              [-1, 64, 16, 16]          57,728
# |    |    └─BasicBlock: 3-4              [-1, 64, 16, 16]          73,984
# |    └─Sequential: 2-5                   [-1, 128, 8, 8]           --
# |    |    └─BasicBlock: 3-5              [-1, 128, 8, 8]           230,144
# |    |    └─BasicBlock: 3-6              [-1, 128, 8, 8]           295,424
# |    └─Sequential: 2-6                   [-1, 256, 4, 4]           --
# |    |    └─BasicBlock: 3-7              [-1, 256, 4, 4]           919,040
# |    |    └─BasicBlock: 3-8              [-1, 256, 4, 4]           1,180,672
# |    └─Dropout: 2-7                      [-1, 256]                 --
# |    └─Linear: 2-8                       [-1, 10]                  2,570
# ==========================================================================================
# Total params: 2,797,610
# Trainable params: 2,797,610
# Non-trainable params: 0
# Total mult-adds (M): 146.15
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.25
# Params size (MB): 10.67
# Estimated Total Size (MB): 14.93
# ==========================================================================================
#
# Epoch: 0
# Training epoch 0: Loss=2.352 Acc=11.502
# Testing epoch 0: Loss=2.289 Acc=16.420
# Saving..
# Epoch 0: 31.22s
# Train: 28.53s, Test: 2.69s
#
# Epoch: 1
# Training epoch 1: Loss=2.310 Acc=13.836
# Testing epoch 1: Loss=2.249 Acc=18.430
# Saving..
# Epoch 1: 63.44s
# Train: 29.60s, Test: 2.62s
#
# Epoch: 2
# Training epoch 2: Loss=2.275 Acc=15.676
# Testing epoch 2: Loss=2.211 Acc=20.130
# Saving..
# Epoch 2: 95.79s
# Train: 29.65s, Test: 2.69s
#
# Epoch: 3
# Training epoch 3: Loss=2.244 Acc=17.298
# Testing epoch 3: Loss=2.176 Acc=21.110
# Saving..
# Epoch 3: 127.84s
# Train: 29.54s, Test: 2.51s
#
# Epoch: 4
# Training epoch 4: Loss=2.212 Acc=18.582
# Testing epoch 4: Loss=2.137 Acc=21.860
# Saving..
# Epoch 4: 159.80s
# Train: 29.39s, Test: 2.57s
#
# Epoch: 5
# Training epoch 5: Loss=2.175 Acc=19.938
# Testing epoch 5: Loss=2.103 Acc=22.110
# Saving..
# Epoch 5: 192.23s
# Train: 29.81s, Test: 2.62s
#
# Epoch: 6
# Training epoch 6: Loss=2.141 Acc=20.618
# Testing epoch 6: Loss=2.068 Acc=22.750
# Saving..
# Epoch 6: 224.24s
# Train: 29.52s, Test: 2.48s
#
# Epoch: 7
# Training epoch 7: Loss=2.112 Acc=21.258
# Testing epoch 7: Loss=2.044 Acc=23.400
# Saving..
# Epoch 7: 256.73s
# Train: 29.66s, Test: 2.82s
#
# Epoch: 8
# Training epoch 8: Loss=2.088 Acc=21.748
# Testing epoch 8: Loss=2.026 Acc=23.990
# Saving..
# Epoch 8: 289.29s
# Train: 29.98s, Test: 2.58s
#
# Epoch: 9
# Training epoch 9: Loss=2.067 Acc=22.292
# Testing epoch 9: Loss=2.011 Acc=24.520
# Saving..
# Epoch 9: 321.75s
# Train: 30.01s, Test: 2.45s
#
# Epoch: 10
# Training epoch 10: Loss=2.048 Acc=23.062
# Testing epoch 10: Loss=1.997 Acc=24.860
# Saving..
# Epoch 10: 354.27s
# Train: 29.92s, Test: 2.60s
#
# Epoch: 11
# Training epoch 11: Loss=2.029 Acc=23.638
# Testing epoch 11: Loss=1.982 Acc=25.600
# Saving..
# Epoch 11: 387.15s
# Train: 30.22s, Test: 2.65s
#
# Epoch: 12
# Training epoch 12: Loss=2.016 Acc=24.360
# Testing epoch 12: Loss=1.971 Acc=26.020
# Saving..
# Epoch 12: 419.70s
# Train: 30.12s, Test: 2.43s
#
# Epoch: 13
# Training epoch 13: Loss=2.001 Acc=24.566
# Testing epoch 13: Loss=1.954 Acc=26.560
# Saving..
# Epoch 13: 452.20s
# Train: 30.03s, Test: 2.47s
#
# Epoch: 14
# Training epoch 14: Loss=1.986 Acc=25.308
# Testing epoch 14: Loss=1.938 Acc=27.490
# Saving..
# Epoch 14: 484.89s
# Train: 30.09s, Test: 2.60s
#
# Epoch: 15
# Training epoch 15: Loss=1.972 Acc=25.828
# Testing epoch 15: Loss=1.918 Acc=28.290
# Saving..
# Epoch 15: 517.58s
# Train: 30.21s, Test: 2.49s
#
# Epoch: 16
# Training epoch 16: Loss=1.956 Acc=26.516
# Testing epoch 16: Loss=1.906 Acc=29.120
# Saving..
# Epoch 16: 550.18s
# Train: 30.29s, Test: 2.30s
#
# Epoch: 17
# Training epoch 17: Loss=1.945 Acc=26.660
# Testing epoch 17: Loss=1.893 Acc=29.770
# Saving..
# Epoch 17: 582.88s
# Train: 30.29s, Test: 2.42s
#
# Epoch: 18
# Training epoch 18: Loss=1.930 Acc=27.836
# Testing epoch 18: Loss=1.881 Acc=30.160
# Saving..
# Epoch 18: 615.66s
# Train: 30.32s, Test: 2.46s
#
# Epoch: 19
# Training epoch 19: Loss=1.921 Acc=27.762
# Testing epoch 19: Loss=1.866 Acc=30.870
# Saving..
# Epoch 19: 648.28s
# Train: 30.27s, Test: 2.34s
#
# Epoch: 20
# Training epoch 20: Loss=1.908 Acc=28.586
# Testing epoch 20: Loss=1.853 Acc=31.520
# Saving..
# Epoch 20: 680.71s
# Train: 30.14s, Test: 2.29s
#
# Epoch: 21
# Training epoch 21: Loss=1.894 Acc=29.056
# Testing epoch 21: Loss=1.839 Acc=32.260
# Saving..
# Epoch 21: 713.06s
# Train: 30.02s, Test: 2.33s
#
# Epoch: 22
# Training epoch 22: Loss=1.884 Acc=29.340
# Testing epoch 22: Loss=1.827 Acc=32.640
# Saving..
# Epoch 22: 745.52s
# Train: 30.00s, Test: 2.46s
#
# Epoch: 23
# Training epoch 23: Loss=1.874 Acc=29.706
# Testing epoch 23: Loss=1.815 Acc=33.090
# Saving..
# Epoch 23: 778.06s
# Train: 29.93s, Test: 2.62s
#
# Epoch: 24
# Training epoch 24: Loss=1.864 Acc=30.320
# Testing epoch 24: Loss=1.803 Acc=33.560
# Saving..
# Epoch 24: 810.68s
# Train: 29.90s, Test: 2.71s
#
# Epoch: 25
# Training epoch 25: Loss=1.855 Acc=30.540
# Testing epoch 25: Loss=1.792 Acc=33.960
# Saving..
# Epoch 25: 843.12s
# Train: 29.84s, Test: 2.60s
#
# Epoch: 26
# Training epoch 26: Loss=1.847 Acc=30.832
# Testing epoch 26: Loss=1.782 Acc=34.220
# Saving..
# Epoch 26: 875.47s
# Train: 29.64s, Test: 2.70s
#
# Epoch: 27
# Training epoch 27: Loss=1.837 Acc=31.208
# Testing epoch 27: Loss=1.768 Acc=34.980
# Saving..
# Epoch 27: 907.84s
# Train: 29.67s, Test: 2.70s
#
# Epoch: 28
# Training epoch 28: Loss=1.826 Acc=31.590
# Testing epoch 28: Loss=1.761 Acc=34.910
# Epoch 28: 939.86s
# Train: 29.38s, Test: 2.65s
#
# Epoch: 29
# Training epoch 29: Loss=1.816 Acc=32.148
# Testing epoch 29: Loss=1.749 Acc=35.480
# Saving..
# Epoch 29: 972.10s
# Train: 29.36s, Test: 2.88s
#
# Epoch: 30
# Training epoch 30: Loss=1.809 Acc=32.282
# Testing epoch 30: Loss=1.737 Acc=35.810
# Saving..
# Epoch 30: 1004.28s
# Train: 29.45s, Test: 2.73s
#
# Epoch: 31
# Training epoch 31: Loss=1.800 Acc=32.654
# Testing epoch 31: Loss=1.730 Acc=36.140
# Saving..
# Epoch 31: 1036.26s
# Train: 29.18s, Test: 2.81s
#
# Epoch: 32
# Training epoch 32: Loss=1.794 Acc=32.916
# Testing epoch 32: Loss=1.719 Acc=36.580
# Saving..
# Epoch 32: 1068.49s
# Train: 29.45s, Test: 2.77s
#
# Epoch: 33
# Training epoch 33: Loss=1.787 Acc=33.190
# Testing epoch 33: Loss=1.709 Acc=36.770
# Saving..
# Epoch 33: 1100.92s
# Train: 29.51s, Test: 2.92s
#
# Epoch: 34
# Training epoch 34: Loss=1.778 Acc=33.552
# Testing epoch 34: Loss=1.700 Acc=37.150
# Saving..
# Epoch 34: 1133.12s
# Train: 29.33s, Test: 2.86s
#
# Epoch: 35
# Training epoch 35: Loss=1.773 Acc=33.698
# Testing epoch 35: Loss=1.692 Acc=37.510
# Saving..
# Epoch 35: 1165.28s
# Train: 29.34s, Test: 2.83s
#
# Epoch: 36
# Training epoch 36: Loss=1.766 Acc=33.714
# Testing epoch 36: Loss=1.686 Acc=37.490
# Epoch 36: 1197.43s
# Train: 29.49s, Test: 2.66s
#
# Epoch: 37
# Training epoch 37: Loss=1.758 Acc=34.214
# Testing epoch 37: Loss=1.675 Acc=37.880
# Saving..
# Epoch 37: 1229.35s
# Train: 29.16s, Test: 2.76s
#
# Epoch: 38
# Training epoch 38: Loss=1.752 Acc=34.548
# Testing epoch 38: Loss=1.672 Acc=38.060
# Saving..
# Epoch 38: 1261.28s
# Train: 29.25s, Test: 2.68s
#
# Epoch: 39
# Training epoch 39: Loss=1.747 Acc=34.540
# Testing epoch 39: Loss=1.666 Acc=38.310
# Saving..
# Epoch 39: 1293.68s
# Train: 29.53s, Test: 2.87s
#
# Epoch: 40
# Training epoch 40: Loss=1.739 Acc=35.294
# Testing epoch 40: Loss=1.657 Acc=38.680
# Saving..
# Epoch 40: 1325.86s
# Train: 29.43s, Test: 2.74s
#
# Epoch: 41
# Training epoch 41: Loss=1.736 Acc=35.322
# Testing epoch 41: Loss=1.650 Acc=38.980
# Saving..
# Epoch 41: 1358.08s
# Train: 29.40s, Test: 2.82s
#
# Epoch: 42
# Training epoch 42: Loss=1.727 Acc=35.584
# Testing epoch 42: Loss=1.647 Acc=38.950
# Epoch 42: 1390.48s
# Train: 29.52s, Test: 2.89s
#
# Epoch: 43
# Training epoch 43: Loss=1.720 Acc=35.680
# Testing epoch 43: Loss=1.639 Acc=39.290
# Saving..
# Epoch 43: 1422.25s
# Train: 29.05s, Test: 2.72s
#
# Epoch: 44
# Training epoch 44: Loss=1.715 Acc=35.770
# Testing epoch 44: Loss=1.632 Acc=39.560
# Saving..
# Epoch 44: 1454.22s
# Train: 29.35s, Test: 2.61s
#
# Epoch: 45
# Training epoch 45: Loss=1.708 Acc=36.504
# Testing epoch 45: Loss=1.629 Acc=39.560
# Epoch 45: 1486.36s
# Train: 29.55s, Test: 2.60s
#
# Epoch: 46
# Training epoch 46: Loss=1.705 Acc=36.474
# Testing epoch 46: Loss=1.621 Acc=39.790
# Saving..
# Epoch 46: 1518.58s
# Train: 29.39s, Test: 2.83s
#
# Epoch: 47
# Training epoch 47: Loss=1.698 Acc=36.870
# Testing epoch 47: Loss=1.615 Acc=40.090
# Saving..
# Epoch 47: 1550.70s
# Train: 29.44s, Test: 2.67s
#
# Epoch: 48
# Training epoch 48: Loss=1.693 Acc=37.102
# Testing epoch 48: Loss=1.607 Acc=40.600
# Saving..
# Epoch 48: 1582.83s
# Train: 29.48s, Test: 2.66s
#
# Epoch: 49
# Training epoch 49: Loss=1.688 Acc=37.264
# Testing epoch 49: Loss=1.605 Acc=40.540
# Epoch 49: 1615.01s
# Train: 29.42s, Test: 2.75s
#
# Epoch: 50
# Training epoch 50: Loss=1.685 Acc=37.416
# Testing epoch 50: Loss=1.597 Acc=40.830
# Saving..
# Epoch 50: 1647.17s
# Train: 29.36s, Test: 2.80s
#
# Epoch: 51
# Training epoch 51: Loss=1.680 Acc=37.310
# Testing epoch 51: Loss=1.593 Acc=41.090
# Saving..
# Epoch 51: 1679.19s
# Train: 29.21s, Test: 2.82s
#
# Epoch: 52
# Training epoch 52: Loss=1.673 Acc=37.726
# Testing epoch 52: Loss=1.585 Acc=41.320
# Saving..
# Epoch 52: 1711.31s
# Train: 29.28s, Test: 2.84s
#
# Epoch: 53
# Training epoch 53: Loss=1.672 Acc=37.554
# Testing epoch 53: Loss=1.582 Acc=41.250
# Epoch 53: 1743.61s
# Train: 29.39s, Test: 2.91s
#
# Epoch: 54
# Training epoch 54: Loss=1.664 Acc=38.206
# Testing epoch 54: Loss=1.580 Acc=41.420
# Saving..
# Epoch 54: 1775.84s
# Train: 29.47s, Test: 2.76s
#
# Epoch: 55
# Training epoch 55: Loss=1.664 Acc=38.086
# Testing epoch 55: Loss=1.576 Acc=41.370
# Epoch 55: 1808.25s
# Train: 29.55s, Test: 2.86s
#
# Epoch: 56
# Training epoch 56: Loss=1.655 Acc=38.728
# Testing epoch 56: Loss=1.574 Acc=41.500
# Saving..
# Epoch 56: 1840.52s
# Train: 29.47s, Test: 2.81s
#
# Epoch: 57
# Training epoch 57: Loss=1.651 Acc=38.530
# Testing epoch 57: Loss=1.564 Acc=41.820
# Saving..
# Epoch 57: 1873.16s
# Train: 29.72s, Test: 2.92s
#
# Epoch: 58
# Training epoch 58: Loss=1.647 Acc=38.718
# Testing epoch 58: Loss=1.559 Acc=42.170
# Saving..
# Epoch 58: 1905.43s
# Train: 29.50s, Test: 2.78s
#
# Epoch: 59
# Training epoch 59: Loss=1.645 Acc=38.980
# Testing epoch 59: Loss=1.554 Acc=42.350
# Saving..
# Epoch 59: 1937.78s
# Train: 29.62s, Test: 2.73s
#
# Epoch: 60
# Training epoch 60: Loss=1.641 Acc=39.296
# Testing epoch 60: Loss=1.553 Acc=42.290
# Epoch 60: 1969.79s
# Train: 29.30s, Test: 2.72s
#
# Epoch: 61
# Training epoch 61: Loss=1.639 Acc=38.890
# Testing epoch 61: Loss=1.551 Acc=42.400
# Saving..
# Epoch 61: 2001.91s
# Train: 29.35s, Test: 2.77s
#
# Epoch: 62
# Training epoch 62: Loss=1.634 Acc=39.406
# Testing epoch 62: Loss=1.546 Acc=42.690
# Saving..
# Epoch 62: 2033.96s
# Train: 29.41s, Test: 2.64s
#
# Epoch: 63
# Training epoch 63: Loss=1.629 Acc=39.672
# Testing epoch 63: Loss=1.540 Acc=42.740
# Saving..
# Epoch 63: 2066.17s
# Train: 29.54s, Test: 2.67s
#
# Epoch: 64
# Training epoch 64: Loss=1.627 Acc=39.494
# Testing epoch 64: Loss=1.535 Acc=42.810
# Saving..
# Epoch 64: 2098.53s
# Train: 29.68s, Test: 2.67s
#
# Epoch: 65
# Training epoch 65: Loss=1.618 Acc=39.944
# Testing epoch 65: Loss=1.533 Acc=42.940
# Saving..
# Epoch 65: 2130.71s
# Train: 29.54s, Test: 2.64s
#
# Epoch: 66
# Training epoch 66: Loss=1.618 Acc=40.086
# Testing epoch 66: Loss=1.530 Acc=43.270
# Saving..
# Epoch 66: 2162.91s
# Train: 29.55s, Test: 2.66s
#
# Epoch: 67
# Training epoch 67: Loss=1.611 Acc=40.194
# Testing epoch 67: Loss=1.525 Acc=43.550
# Saving..
# Epoch 67: 2195.55s
# Train: 29.88s, Test: 2.76s
#
# Epoch: 68
# Training epoch 68: Loss=1.609 Acc=40.552
# Testing epoch 68: Loss=1.523 Acc=43.470
# Epoch 68: 2227.73s
# Train: 29.65s, Test: 2.53s
#
# Epoch: 69
# Training epoch 69: Loss=1.606 Acc=40.320
# Testing epoch 69: Loss=1.520 Acc=43.410
# Epoch 69: 2260.01s
# Train: 29.64s, Test: 2.64s
#
# Epoch: 70
# Training epoch 70: Loss=1.602 Acc=40.688
# Testing epoch 70: Loss=1.514 Acc=43.760
# Saving..
# Epoch 70: 2292.07s
# Train: 29.47s, Test: 2.60s
#
# Epoch: 71
# Training epoch 71: Loss=1.596 Acc=41.008
# Testing epoch 71: Loss=1.512 Acc=43.990
# Saving..
# Epoch 71: 2324.44s
# Train: 29.73s, Test: 2.64s
#
# Epoch: 72
# Training epoch 72: Loss=1.599 Acc=40.740
# Testing epoch 72: Loss=1.508 Acc=43.980
# Epoch 72: 2356.51s
# Train: 29.56s, Test: 2.51s
#
# Epoch: 73
# Training epoch 73: Loss=1.589 Acc=41.166
# Testing epoch 73: Loss=1.503 Acc=44.030
# Saving..
# Epoch 73: 2388.65s
# Train: 29.47s, Test: 2.67s
#
# Epoch: 74
# Training epoch 74: Loss=1.589 Acc=40.990
# Testing epoch 74: Loss=1.502 Acc=44.050
# Saving..
# Epoch 74: 2421.00s
# Train: 29.67s, Test: 2.67s
#
# Epoch: 75
# Training epoch 75: Loss=1.586 Acc=41.198
# Testing epoch 75: Loss=1.501 Acc=44.410
# Saving..
# Epoch 75: 2452.95s
# Train: 29.40s, Test: 2.55s
#
# Epoch: 76
# Training epoch 76: Loss=1.581 Acc=41.494
# Testing epoch 76: Loss=1.494 Acc=44.340
# Epoch 76: 2485.18s
# Train: 29.66s, Test: 2.57s
#
# Epoch: 77
# Training epoch 77: Loss=1.578 Acc=41.642
# Testing epoch 77: Loss=1.491 Acc=44.460
# Saving..
# Epoch 77: 2517.26s
# Train: 29.47s, Test: 2.61s
#
# Epoch: 78
# Training epoch 78: Loss=1.573 Acc=41.818
# Testing epoch 78: Loss=1.486 Acc=44.790
# Saving..
# Epoch 78: 2549.36s
# Train: 29.47s, Test: 2.63s
#
# Epoch: 79
# Training epoch 79: Loss=1.573 Acc=41.640
# Testing epoch 79: Loss=1.486 Acc=44.670
# Epoch 79: 2581.22s
# Train: 29.37s, Test: 2.49s
#
# Epoch: 80
# Training epoch 80: Loss=1.569 Acc=42.058
# Testing epoch 80: Loss=1.484 Acc=44.710
# Epoch 80: 2613.25s
# Train: 29.50s, Test: 2.53s
#
# Epoch: 81
# Training epoch 81: Loss=1.570 Acc=42.056
# Testing epoch 81: Loss=1.481 Acc=44.800
# Saving..
# Epoch 81: 2645.44s
# Train: 29.63s, Test: 2.56s
#
# Epoch: 82
# Training epoch 82: Loss=1.563 Acc=42.462
# Testing epoch 82: Loss=1.478 Acc=45.020
# Saving..
# Epoch 82: 2677.61s
# Train: 29.68s, Test: 2.49s
#
# Epoch: 83
# Training epoch 83: Loss=1.562 Acc=42.286
# Testing epoch 83: Loss=1.475 Acc=44.910
# Epoch 83: 2709.71s
# Train: 29.77s, Test: 2.33s
#
# Epoch: 84
# Training epoch 84: Loss=1.560 Acc=42.278
# Testing epoch 84: Loss=1.473 Acc=45.110
# Saving..
# Epoch 84: 2742.17s
# Train: 29.89s, Test: 2.57s
#
# Epoch: 85
# Training epoch 85: Loss=1.556 Acc=42.670
# Testing epoch 85: Loss=1.468 Acc=45.340
# Saving..
# Epoch 85: 2774.80s
# Train: 30.03s, Test: 2.60s
#
# Epoch: 86
# Training epoch 86: Loss=1.554 Acc=42.430
# Testing epoch 86: Loss=1.466 Acc=45.440
# Saving..
# Epoch 86: 2807.46s
# Train: 30.09s, Test: 2.57s
#
# Epoch: 87
# Training epoch 87: Loss=1.550 Acc=42.632
# Testing epoch 87: Loss=1.464 Acc=45.610
# Saving..
# Epoch 87: 2840.02s
# Train: 30.05s, Test: 2.51s
#
# Epoch: 88
# Training epoch 88: Loss=1.547 Acc=42.874
# Testing epoch 88: Loss=1.460 Acc=45.700
# Saving..
# Epoch 88: 2872.90s
# Train: 30.32s, Test: 2.57s
#
# Epoch: 89
# Training epoch 89: Loss=1.546 Acc=42.938
# Testing epoch 89: Loss=1.460 Acc=45.700
# Epoch 89: 2905.67s
# Train: 30.10s, Test: 2.67s
#
# Epoch: 90
# Training epoch 90: Loss=1.544 Acc=43.086
# Testing epoch 90: Loss=1.454 Acc=45.840
# Saving..
# Epoch 90: 2938.86s
# Train: 30.60s, Test: 2.59s
#
# Epoch: 91
# Training epoch 91: Loss=1.539 Acc=43.494
# Testing epoch 91: Loss=1.452 Acc=45.950
# Saving..
# Epoch 91: 2971.99s
# Train: 30.37s, Test: 2.77s
#
# Epoch: 92
# Training epoch 92: Loss=1.537 Acc=43.212
# Testing epoch 92: Loss=1.451 Acc=46.090
# Saving..
# Epoch 92: 3004.79s
# Train: 30.13s, Test: 2.67s
#
# Epoch: 93
# Training epoch 93: Loss=1.533 Acc=43.264
# Testing epoch 93: Loss=1.449 Acc=46.190
# Saving..
# Epoch 93: 3037.21s
# Train: 29.82s, Test: 2.61s
#
# Epoch: 94
# Training epoch 94: Loss=1.530 Acc=43.750
# Testing epoch 94: Loss=1.447 Acc=46.240
# Saving..
# Epoch 94: 3069.70s
# Train: 29.67s, Test: 2.82s
#
# Epoch: 95
# Training epoch 95: Loss=1.527 Acc=43.826
# Testing epoch 95: Loss=1.441 Acc=46.400
# Saving..
# Epoch 95: 3101.98s
# Train: 29.55s, Test: 2.73s
#
# Epoch: 96
# Training epoch 96: Loss=1.527 Acc=43.640
# Testing epoch 96: Loss=1.440 Acc=46.450
# Saving..
# Epoch 96: 3134.53s
# Train: 29.71s, Test: 2.84s
#
# Epoch: 97
# Training epoch 97: Loss=1.526 Acc=43.872
# Testing epoch 97: Loss=1.436 Acc=46.630
# Saving..
# Epoch 97: 3166.71s
# Train: 29.41s, Test: 2.77s
#
# Epoch: 98
# Training epoch 98: Loss=1.524 Acc=43.972
# Testing epoch 98: Loss=1.440 Acc=46.770
# Saving..
# Epoch 98: 3198.85s
# Train: 29.42s, Test: 2.72s
#
# Epoch: 99
# Training epoch 99: Loss=1.519 Acc=43.964
# Testing epoch 99: Loss=1.434 Acc=46.720
# Epoch 99: 3231.01s
# Train: 29.42s, Test: 2.74s
#
# Epoch: 100
# Training epoch 100: Loss=1.519 Acc=44.076
# Testing epoch 100: Loss=1.434 Acc=46.780
# Saving..
# Epoch 100: 3263.31s
# Train: 29.52s, Test: 2.79s
#
# Epoch: 101
# Training epoch 101: Loss=1.516 Acc=44.082
# Testing epoch 101: Loss=1.430 Acc=46.810
# Saving..
# Epoch 101: 3295.36s
# Train: 29.37s, Test: 2.67s
#
# Epoch: 102
# Training epoch 102: Loss=1.515 Acc=44.162
# Testing epoch 102: Loss=1.431 Acc=46.980
# Saving..
# Epoch 102: 3327.31s
# Train: 29.32s, Test: 2.63s
#
# Epoch: 103
# Training epoch 103: Loss=1.509 Acc=44.472
# Testing epoch 103: Loss=1.421 Acc=47.230
# Saving..
# Epoch 103: 3359.18s
# Train: 29.22s, Test: 2.65s
#
# Epoch: 104
# Training epoch 104: Loss=1.507 Acc=44.464
# Testing epoch 104: Loss=1.425 Acc=47.290
# Saving..
# Epoch 104: 3391.45s
# Train: 29.49s, Test: 2.79s
#
# Epoch: 105
# Training epoch 105: Loss=1.502 Acc=44.686
# Testing epoch 105: Loss=1.423 Acc=47.430
# Saving..
# Epoch 105: 3423.62s
# Train: 29.46s, Test: 2.71s
#
# Epoch: 106
# Training epoch 106: Loss=1.502 Acc=44.748
# Testing epoch 106: Loss=1.417 Acc=47.520
# Saving..
# Epoch 106: 3455.89s
# Train: 29.27s, Test: 3.00s
#
# Epoch: 107
# Training epoch 107: Loss=1.504 Acc=44.476
# Testing epoch 107: Loss=1.415 Acc=47.650
# Saving..
# Epoch 107: 3488.26s
# Train: 29.53s, Test: 2.84s
#
# Epoch: 108
# Training epoch 108: Loss=1.503 Acc=44.848
# Testing epoch 108: Loss=1.414 Acc=47.850
# Saving..
# Epoch 108: 3520.41s
# Train: 29.45s, Test: 2.70s
#
# Epoch: 109
# Training epoch 109: Loss=1.494 Acc=45.474
# Testing epoch 109: Loss=1.412 Acc=47.820
# Epoch 109: 3552.49s
# Train: 29.41s, Test: 2.67s
#
# Epoch: 110
# Training epoch 110: Loss=1.498 Acc=45.008
# Testing epoch 110: Loss=1.411 Acc=47.650
# Epoch 110: 3584.55s
# Train: 29.37s, Test: 2.69s
#
# Epoch: 111
# Training epoch 111: Loss=1.495 Acc=45.086
# Testing epoch 111: Loss=1.408 Acc=48.140
# Saving..
# Epoch 111: 3616.78s
# Train: 29.49s, Test: 2.74s
#
# Epoch: 112
# Training epoch 112: Loss=1.492 Acc=45.084
# Testing epoch 112: Loss=1.408 Acc=48.140
# Epoch 112: 3649.03s
# Train: 29.59s, Test: 2.65s
#
# Epoch: 113
# Training epoch 113: Loss=1.490 Acc=45.426
# Testing epoch 113: Loss=1.403 Acc=48.180
# Saving..
# Epoch 113: 3680.91s
# Train: 29.22s, Test: 2.66s
#
# Epoch: 114
# Training epoch 114: Loss=1.485 Acc=45.430
# Testing epoch 114: Loss=1.404 Acc=48.150
# Epoch 114: 3713.05s
# Train: 29.39s, Test: 2.75s
#
# Epoch: 115
# Training epoch 115: Loss=1.487 Acc=45.364
# Testing epoch 115: Loss=1.402 Acc=48.220
# Saving..
# Epoch 115: 3745.50s
# Train: 29.58s, Test: 2.87s
#
# Epoch: 116
# Training epoch 116: Loss=1.481 Acc=45.548
# Testing epoch 116: Loss=1.397 Acc=48.420
# Saving..
# Epoch 116: 3777.91s
# Train: 29.55s, Test: 2.86s
#
# Epoch: 117
# Training epoch 117: Loss=1.484 Acc=45.462
# Testing epoch 117: Loss=1.398 Acc=48.370
# Epoch 117: 3810.26s
# Train: 29.47s, Test: 2.88s
#
# Epoch: 118
# Training epoch 118: Loss=1.481 Acc=45.504
# Testing epoch 118: Loss=1.394 Acc=48.540
# Saving..
# Epoch 118: 3837.08s
# Train: 25.14s, Test: 1.69s
#
# Epoch: 119
# Training epoch 119: Loss=1.478 Acc=45.718
# Testing epoch 119: Loss=1.391 Acc=48.770
# Saving..
# Epoch 119: 3854.00s
# Train: 15.33s, Test: 1.59s

# %%
plt.plot(range(120),train_acc_history,'-',linewidth=3,label='Train accuracy')
plt.plot(range(120),test_acc_history,'-',linewidth=3,label='Test accuracy')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
