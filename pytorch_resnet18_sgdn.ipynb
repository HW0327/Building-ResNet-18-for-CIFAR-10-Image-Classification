# %%
# %conda update -n base conda
# %conda install pytorch
# %conda install torchvision
# %pip install torch-summary
# %pip install matplotlib
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - conda
#
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   libnsl             conda-forge/linux-64::libnsl-2.0.0-h7f98852_0
#   libsqlite          conda-forge/linux-64::libsqlite-3.40.0-h753d276_0
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h7f98852_1000
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-h166bdaf_4
#   toolz              conda-forge/noarch::toolz-0.12.0-pyhd8ed1ab_0
#
# The following packages will be REMOVED:
#
#   chardet-4.0.0-py39hf3d152e_1
#   libstdcxx-ng-11.2.0-he4da1e4_9
#   six-1.16.0-pyh6c4a22f_0
#   zlib-1.2.11-h516909a_1010
#
# The following packages will be UPDATED:
#
#   _openmp_mutex                                   4.5-1_gnu --> 4.5-2_gnu
#   brotlipy                          0.7.0-py39h3811e60_1001 --> 0.7.0-py39hb9d737c_1005
#   ca-certificates                      2021.5.30-ha878542_0 --> 2022.9.24-ha878542_0
#   certifi            conda-forge/linux-64::certifi-2021.5.~ --> conda-forge/noarch::certifi-2022.9.24-pyhd8ed1ab_0
#   cffi                                1.14.6-py39h4bc2ebd_1 --> 1.15.1-py39he91dace_2
#   charset-normalizer                     2.0.0-pyhd8ed1ab_0 --> 2.1.1-pyhd8ed1ab_0
#   colorama                               0.4.4-pyh9f0ad1d_0 --> 0.4.6-pyhd8ed1ab_0
#   conda                               4.10.3-py39hf3d152e_2 --> 22.9.0-py39hf3d152e_2
#   conda-package-han~                   1.7.3-py39h3811e60_0 --> 1.9.0-py39hb9d737c_1
#   cryptography                         3.4.7-py39hbca0aa6_0 --> 38.0.3-py39h3ccb8fc_0
#   idna                                     3.1-pyhd3deb0d_0 --> 3.4-pyhd8ed1ab_0
#   ld_impl_linux-64                        2.36.1-hea4e1c9_2 --> 2.39-hcc3a1bd_1
#   libffi                                   3.4.2-h9c3ff4c_4 --> 3.4.2-h7f98852_5
#   libgcc-ng                               11.2.0-h1d223b6_9 --> 12.2.0-h65d4601_19
#   libgomp                                 11.2.0-h1d223b6_9 --> 12.2.0-h65d4601_19
#   ncurses                                    6.2-h58526e2_4 --> 6.3-h27087fc_1
#   openssl                                 1.1.1l-h7f98852_0 --> 3.0.7-h166bdaf_0
#   pycosat                           0.6.3-py39h3811e60_1006 --> 0.6.4-py39hb9d737c_1
#   pycparser                               2.20-pyh9f0ad1d_2 --> 2.21-pyhd8ed1ab_0
#   pyopenssl                             20.0.1-pyhd8ed1ab_0 --> 22.1.0-pyhd8ed1ab_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-p~ --> conda-forge/noarch::pysocks-1.7.1-pyha2e5f31_6
#   python                           3.9.7-hb7a2778_2_cpython --> 3.9.13-h2660328_0_cpython
#   readline                                   8.1-h46c0cb4_0 --> 8.1.2-h0f457ee_0
#   requests                              2.26.0-pyhd8ed1ab_0 --> 2.28.1-pyhd8ed1ab_1
#   ruamel_yaml                     0.15.80-py39h3811e60_1004 --> 0.15.80-py39hb9d737c_1008
#   setuptools         conda-forge/linux-64::setuptools-58.0~ --> conda-forge/noarch::setuptools-65.5.1-pyhd8ed1ab_0
#   sqlite                                  3.36.0-h9cd32fc_2 --> 3.40.0-h4ff8645_0
#   tk                                      8.6.11-h27826a3_1 --> 8.6.12-h27826a3_0
#   tqdm                                  4.62.3-pyhd8ed1ab_0 --> 4.64.1-pyhd8ed1ab_0
#   tzdata                                   2021a-he74cb21_1 --> 2022f-h191b570_0
#   urllib3                               1.26.7-pyhd8ed1ab_0 --> 1.26.11-pyhd8ed1ab_0
#   wheel                                 0.37.0-pyhd8ed1ab_1 --> 0.38.4-pyhd8ed1ab_0
#   xz                                       5.2.5-h516909a_1 --> 5.2.6-h166bdaf_0
#   yaml                                     0.2.5-h516909a_0 --> 0.2.5-h7f98852_2
#
#
# Preparing transaction: done
# Verifying transaction: failed
#
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: /opt/conda
#   uid: 1000
#   gid: 100
#
#
#
# Note: you may need to restart the kernel to use updated packages.
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch-summary in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (1.4.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (3.6.2)
# Requirement already satisfied: cycler>=0.10 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.19 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: six>=1.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms

import torchsummary
import matplotlib.pyplot as plt
import os
import sys
import time
import math

# %%
def get_mean_and_std(dataset):
    '''Compute the mean and std value of dataset.'''
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=1, shuffle=True, num_workers=2)
    mean = torch.zeros(3)
    std = torch.zeros(3)
    print('==> Computing mean and std..')
    for inputs, targets in dataloader:
        for i in range(3):
            mean[i] += inputs[:,i,:,:].mean()
            std[i] += inputs[:,i,:,:].std()
    mean.div_(len(dataset))
    std.div_(len(dataset))
    return mean, std


def init_params(net):
    '''Init layer parameters.'''
    for m in net.modules():
        if isinstance(m, nn.Conv2d):
            init.kaiming_normal(m.weight, mode='fan_out')
            if m.bias:
                init.constant(m.bias, 0)
        elif isinstance(m, nn.BatchNorm2d):
            init.constant(m.weight, 1)
            init.constant(m.bias, 0)
        elif isinstance(m, nn.Linear):
            init.normal(m.weight, std=1e-3)
            if m.bias:
                init.constant(m.bias, 0)


# _, term_width = os.popen('stty size', 'r').read().split()
term_width = 50

TOTAL_BAR_LENGTH = 65.
last_time = time.time()
begin_time = last_time


def progress_bar(current, total, msg=None):
    global last_time, begin_time
    if current == 0:
        begin_time = time.time()  # Reset for new bar.

    cur_len = int(TOTAL_BAR_LENGTH*current/total)
    rest_len = int(TOTAL_BAR_LENGTH - cur_len) - 1

    sys.stdout.write(' [')
    for i in range(cur_len):
        sys.stdout.write('=')
    sys.stdout.write('>')
    for i in range(rest_len):
        sys.stdout.write('.')
    sys.stdout.write(']')

    cur_time = time.time()
    step_time = cur_time - last_time
    last_time = cur_time
    tot_time = cur_time - begin_time

    L = []
    L.append('  Step: %s' % format_time(step_time))
    L.append(' | Tot: %s' % format_time(tot_time))
    if msg:
        L.append(' | ' + msg)

    msg = ''.join(L)
    sys.stdout.write(msg)
    for i in range(term_width-int(TOTAL_BAR_LENGTH)-len(msg)-3):
        sys.stdout.write(' ')

    # Go back to the center of the bar.
    for i in range(term_width-int(TOTAL_BAR_LENGTH/2)+2):
        sys.stdout.write('\b')
    sys.stdout.write(' %d/%d ' % (current+1, total))

    if current < total-1:
        sys.stdout.write('\r')
    else:
        sys.stdout.write('\n')
    sys.stdout.flush()


def format_time(seconds):
    days = int(seconds / 3600/24)
    seconds = seconds - days*3600*24
    hours = int(seconds / 3600)
    seconds = seconds - hours*3600
    minutes = int(seconds / 60)
    seconds = seconds - minutes*60
    secondsf = int(seconds)
    seconds = seconds - secondsf
    millis = int(seconds*1000)

    f = ''
    i = 1
    if days > 0:
        f += str(days) + 'D'
        i += 1
    if hours > 0 and i <= 2:
        f += str(hours) + 'h'
        i += 1
    if minutes > 0 and i <= 2:
        f += str(minutes) + 'm'
        i += 1
    if secondsf > 0 and i <= 2:
        f += str(secondsf) + 's'
        i += 1
    if millis > 0 and i <= 2:
        f += str(millis) + 'ms'
        i += 1
    if f == '':
        f = '0ms'
    return f

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 32

        self.conv1 = nn.Conv2d(3, 32, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.layer1 = self._make_layer(block, 32, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 64, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 256, num_blocks[3], stride=2)
        self.dropout = nn.Dropout(p=0.2)
        self.linear = nn.Linear(256*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.dropout(out)
        out = self.linear(out)
        return out

# %%
def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])


def ResNet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])


def ResNet101():
    return ResNet(Bottleneck, [3, 4, 23, 3])


def ResNet152():
    return ResNet(Bottleneck, [3, 8, 36, 3])

# %%
# parser = argparse.ArgumentParser(description='PyTorch CIFAR10 Training')
# parser.add_argument('--lr', default=0.1, type=float, help='learning rate')
# parser.add_argument('--resume', '-r', action='store_true',
#                     help='resume from checkpoint')
# args = parser.parse_args()

device = 'cuda' if torch.cuda.is_available() else 'cpu'
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch
Learning_rate = 0.0001
Resume = False
Optimizer = 'sgdn'  # sgd, sgdn, adagrad, adadelta or adam
Batch_size = 128


# Data
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=Batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=100, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# Model
print('==> Building model..')
net = ResNet18()
net = net.to(device)
if device == 'cuda':
    net = torch.nn.DataParallel(net)
    cudnn.benchmark = True

if Resume:
    # Load checkpoint.
    print('==> Resuming from checkpoint..')
    assert os.path.isdir('checkpoint'), 'Error: no checkpoint directory found!'
    checkpoint = torch.load('./checkpoint/ckpt.pth')
    net.load_state_dict(checkpoint['net'])
    best_acc = checkpoint['acc']
    start_epoch = checkpoint['epoch']

criterion = nn.CrossEntropyLoss(reduction='sum')
optimizer = optim.SGD(net.parameters(), lr=Learning_rate,
                      momentum=0.9, weight_decay=5e-4)
if Optimizer == 'sgdn':
    optimizer = optim.SGD(net.parameters(), lr=Learning_rate,
                    momentum=0.9, weight_decay=5e-4, nesterov=True)
elif Optimizer == 'adagrad':
    optimizer = optim.Adagrad(net.parameters(), lr=Learning_rate,
                              weight_decay=5e-4)
elif Optimizer == 'adadelta':
    optimizer = optim.Adadelta(net.parameters(), lr=Learning_rate,
                               weight_decay=5e-4)
elif Optimizer == 'adam':
    optimizer = optim.Adam(net.parameters(), lr=Learning_rate,
                           weight_decay=5e-4)
# scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)

torchsummary.summary(net, (3, 32, 32))


# Training
def train(epoch):
    print('\nEpoch: %d' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    total_training_time = 0
    time1 = torch.cuda.Event(enable_timing=True)
    time2 = torch.cuda.Event(enable_timing=True)
    time1.record()
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        time2.record()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        torch.cuda.synchronize()
        
        total_training_time += time1.elapsed_time(time2)
        
    avg_loss = train_loss/total
    acc = 100.*correct/total
    print('Training epoch %d: Loss=%.3f Acc=%.3f' %
          (epoch, avg_loss, acc))
    return avg_loss, acc


def test(epoch):
    global best_acc
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
        
    avg_loss = test_loss/total
    acc = 100.*correct/total
    print('Testing epoch %d: Loss=%.3f Acc=%.3f' %
          (epoch, avg_loss, acc))

    # Save checkpoint.
    acc = 100.*correct/total
    if acc > best_acc:
        print('Saving..')
        state = {
            'net': net.state_dict(),
            'acc': acc,
            'epoch': epoch,
        }
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        torch.save(state, './checkpoint/ckpt.pth')
        best_acc = acc
        
    return avg_loss, acc


filename = Optimizer + '_' + str(Batch_size) + '_' + str(Learning_rate) + '_dropout.csv'
file = open(filename, 'w')
file.write('train_avg_loss, train_acc, test_avg_loss, test_acc, train_time, test_time\n')
Start_time = time.perf_counter()
train_acc_history = []
test_acc_history = []
for epoch in range(start_epoch, start_epoch+120):
    time1 = time.perf_counter()
    train_avg_loss, train_acc = train(epoch)
    time2 = time.perf_counter()
    test_avg_loss, test_acc = test(epoch)
    Cur_time = time.perf_counter()
    # scheduler.step()
    train_acc_history.append(train_acc)
    test_acc_history.append(test_acc)
    print('Epoch %d: %.2fs' % (epoch, Cur_time - Start_time))
    print('Train: %.2fs, Test: %.2fs' % (time2 - time1, Cur_time - time2))
    file.write('%.3f, %.3f, %.3f, %.3f, %.2f, %.2f\n' %
               (train_avg_loss, train_acc, test_avg_loss, test_acc,
                time2 - time1, Cur_time - time2))
file.close()
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─ResNet: 1-1                            [-1, 10]                  --
# |    └─Conv2d: 2-1                       [-1, 32, 32, 32]          864
# |    └─BatchNorm2d: 2-2                  [-1, 32, 32, 32]          64
# |    └─Sequential: 2-3                   [-1, 32, 32, 32]          --
# |    |    └─BasicBlock: 3-1              [-1, 32, 32, 32]          18,560
# |    |    └─BasicBlock: 3-2              [-1, 32, 32, 32]          18,560
# |    └─Sequential: 2-4                   [-1, 64, 16, 16]          --
# |    |    └─BasicBlock: 3-3              [-1, 64, 16, 16]          57,728
# |    |    └─BasicBlock: 3-4              [-1, 64, 16, 16]          73,984
# |    └─Sequential: 2-5                   [-1, 128, 8, 8]           --
# |    |    └─BasicBlock: 3-5              [-1, 128, 8, 8]           230,144
# |    |    └─BasicBlock: 3-6              [-1, 128, 8, 8]           295,424
# |    └─Sequential: 2-6                   [-1, 256, 4, 4]           --
# |    |    └─BasicBlock: 3-7              [-1, 256, 4, 4]           919,040
# |    |    └─BasicBlock: 3-8              [-1, 256, 4, 4]           1,180,672
# |    └─Dropout: 2-7                      [-1, 256]                 --
# |    └─Linear: 2-8                       [-1, 10]                  2,570
# ==========================================================================================
# Total params: 2,797,610
# Trainable params: 2,797,610
# Non-trainable params: 0
# Total mult-adds (M): 146.15
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.25
# Params size (MB): 10.67
# Estimated Total Size (MB): 14.93
# ==========================================================================================
#
# Epoch: 0
# Training epoch 0: Loss=1.460 Acc=46.062
# Testing epoch 0: Loss=1.420 Acc=53.860
# Saving..
# Epoch 0: 33.03s
# Train: 29.98s, Test: 3.05s
#
# Epoch: 1
# Training epoch 1: Loss=0.977 Acc=65.026
# Testing epoch 1: Loss=0.947 Acc=67.730
# Saving..
# Epoch 1: 64.45s
# Train: 28.42s, Test: 3.01s
#
# Epoch: 2
# Training epoch 2: Loss=0.762 Acc=73.286
# Testing epoch 2: Loss=0.966 Acc=69.670
# Saving..
# Epoch 2: 95.89s
# Train: 28.62s, Test: 2.82s
#
# Epoch: 3
# Training epoch 3: Loss=0.646 Acc=77.576
# Testing epoch 3: Loss=0.641 Acc=78.390
# Saving..
# Epoch 3: 128.11s
# Train: 28.68s, Test: 3.53s
#
# Epoch: 4
# Training epoch 4: Loss=0.576 Acc=80.086
# Testing epoch 4: Loss=0.569 Acc=81.090
# Saving..
# Epoch 4: 160.18s
# Train: 28.74s, Test: 3.33s
#
# Epoch: 5
# Training epoch 5: Loss=0.518 Acc=82.072
# Testing epoch 5: Loss=0.600 Acc=79.620
# Epoch 5: 193.09s
# Train: 29.04s, Test: 3.87s
#
# Epoch: 6
# Training epoch 6: Loss=0.474 Acc=83.672
# Testing epoch 6: Loss=0.529 Acc=82.060
# Saving..
# Epoch 6: 236.17s
# Train: 38.25s, Test: 4.83s
#
# Epoch: 7
# Training epoch 7: Loss=0.435 Acc=84.814
# Testing epoch 7: Loss=0.636 Acc=79.690
# Epoch 7: 282.87s
# Train: 41.68s, Test: 5.02s
#
# Epoch: 8
# Training epoch 8: Loss=0.407 Acc=85.864
# Testing epoch 8: Loss=0.467 Acc=84.260
# Saving..
# Epoch 8: 341.34s
# Train: 54.60s, Test: 3.86s
#
# Epoch: 9
# Training epoch 9: Loss=0.382 Acc=86.684
# Testing epoch 9: Loss=0.496 Acc=84.220
# Epoch 9: 372.69s
# Train: 28.83s, Test: 2.52s
#
# Epoch: 10
# Training epoch 10: Loss=0.359 Acc=87.644
# Testing epoch 10: Loss=0.456 Acc=84.390
# Saving..
# Epoch 10: 404.56s
# Train: 29.26s, Test: 2.60s
#
# Epoch: 11
# Training epoch 11: Loss=0.340 Acc=88.060
# Testing epoch 11: Loss=0.493 Acc=84.090
# Epoch 11: 436.39s
# Train: 29.47s, Test: 2.37s
#
# Epoch: 12
# Training epoch 12: Loss=0.317 Acc=89.086
# Testing epoch 12: Loss=0.475 Acc=84.850
# Saving..
# Epoch 12: 468.27s
# Train: 29.24s, Test: 2.65s
#
# Epoch: 13
# Training epoch 13: Loss=0.300 Acc=89.456
# Testing epoch 13: Loss=0.417 Acc=86.400
# Saving..
# Epoch 13: 500.10s
# Train: 29.12s, Test: 2.70s
#
# Epoch: 14
# Training epoch 14: Loss=0.288 Acc=90.062
# Testing epoch 14: Loss=0.416 Acc=86.810
# Saving..
# Epoch 14: 531.43s
# Train: 28.65s, Test: 2.68s
#
# Epoch: 15
# Training epoch 15: Loss=0.269 Acc=90.610
# Testing epoch 15: Loss=0.439 Acc=86.600
# Epoch 15: 562.58s
# Train: 28.51s, Test: 2.64s
#
# Epoch: 16
# Training epoch 16: Loss=0.259 Acc=91.048
# Testing epoch 16: Loss=0.379 Acc=87.760
# Saving..
# Epoch 16: 593.69s
# Train: 28.25s, Test: 2.87s
#
# Epoch: 17
# Training epoch 17: Loss=0.243 Acc=91.470
# Testing epoch 17: Loss=0.395 Acc=87.230
# Epoch 17: 624.54s
# Train: 28.22s, Test: 2.63s
#
# Epoch: 18
# Training epoch 18: Loss=0.235 Acc=91.858
# Testing epoch 18: Loss=0.403 Acc=87.760
# Epoch 18: 655.82s
# Train: 28.33s, Test: 2.95s
#
# Epoch: 19
# Training epoch 19: Loss=0.223 Acc=92.102
# Testing epoch 19: Loss=0.361 Acc=88.300
# Saving..
# Epoch 19: 687.16s
# Train: 28.56s, Test: 2.78s
#
# Epoch: 20
# Training epoch 20: Loss=0.212 Acc=92.652
# Testing epoch 20: Loss=0.385 Acc=87.730
# Epoch 20: 718.86s
# Train: 28.88s, Test: 2.82s
#
# Epoch: 21
# Training epoch 21: Loss=0.204 Acc=92.824
# Testing epoch 21: Loss=0.385 Acc=88.310
# Saving..
# Epoch 21: 750.38s
# Train: 28.81s, Test: 2.70s
#
# Epoch: 22
# Training epoch 22: Loss=0.196 Acc=93.062
# Testing epoch 22: Loss=0.373 Acc=88.610
# Saving..
# Epoch 22: 781.72s
# Train: 28.49s, Test: 2.84s
#
# Epoch: 23
# Training epoch 23: Loss=0.185 Acc=93.508
# Testing epoch 23: Loss=0.358 Acc=89.190
# Saving..
# Epoch 23: 813.21s
# Train: 28.69s, Test: 2.80s
#
# Epoch: 24
# Training epoch 24: Loss=0.182 Acc=93.574
# Testing epoch 24: Loss=0.362 Acc=89.210
# Saving..
# Epoch 24: 844.80s
# Train: 28.77s, Test: 2.83s
#
# Epoch: 25
# Training epoch 25: Loss=0.171 Acc=93.938
# Testing epoch 25: Loss=0.432 Acc=87.580
# Epoch 25: 876.03s
# Train: 28.38s, Test: 2.84s
#
# Epoch: 26
# Training epoch 26: Loss=0.165 Acc=94.212
# Testing epoch 26: Loss=0.479 Acc=86.610
# Epoch 26: 907.33s
# Train: 28.50s, Test: 2.80s
#
# Epoch: 27
# Training epoch 27: Loss=0.154 Acc=94.570
# Testing epoch 27: Loss=0.408 Acc=88.230
# Epoch 27: 938.81s
# Train: 28.73s, Test: 2.74s
#
# Epoch: 28
# Training epoch 28: Loss=0.148 Acc=94.712
# Testing epoch 28: Loss=0.376 Acc=89.120
# Epoch 28: 970.28s
# Train: 28.65s, Test: 2.82s
#
# Epoch: 29
# Training epoch 29: Loss=0.145 Acc=94.792
# Testing epoch 29: Loss=0.400 Acc=88.490
# Epoch 29: 1001.81s
# Train: 28.76s, Test: 2.77s
#
# Epoch: 30
# Training epoch 30: Loss=0.145 Acc=94.816
# Testing epoch 30: Loss=0.354 Acc=90.070
# Saving..
# Epoch 30: 1033.23s
# Train: 28.70s, Test: 2.71s
#
# Epoch: 31
# Training epoch 31: Loss=0.134 Acc=95.284
# Testing epoch 31: Loss=0.417 Acc=88.450
# Epoch 31: 1064.53s
# Train: 28.57s, Test: 2.73s
#
# Epoch: 32
# Training epoch 32: Loss=0.130 Acc=95.404
# Testing epoch 32: Loss=0.399 Acc=89.030
# Epoch 32: 1096.10s
# Train: 28.72s, Test: 2.85s
#
# Epoch: 33
# Training epoch 33: Loss=0.123 Acc=95.632
# Testing epoch 33: Loss=0.375 Acc=89.550
# Epoch 33: 1127.43s
# Train: 28.42s, Test: 2.91s
#
# Epoch: 34
# Training epoch 34: Loss=0.117 Acc=95.812
# Testing epoch 34: Loss=0.380 Acc=89.350
# Epoch 34: 1159.39s
# Train: 29.13s, Test: 2.83s
#
# Epoch: 35
# Training epoch 35: Loss=0.115 Acc=95.790
# Testing epoch 35: Loss=0.371 Acc=89.670
# Epoch 35: 1190.91s
# Train: 28.72s, Test: 2.81s
#
# Epoch: 36
# Training epoch 36: Loss=0.112 Acc=96.032
# Testing epoch 36: Loss=0.390 Acc=89.290
# Epoch 36: 1222.04s
# Train: 28.46s, Test: 2.67s
#
# Epoch: 37
# Training epoch 37: Loss=0.104 Acc=96.386
# Testing epoch 37: Loss=0.357 Acc=90.080
# Saving..
# Epoch 37: 1253.46s
# Train: 28.52s, Test: 2.90s
#
# Epoch: 38
# Training epoch 38: Loss=0.100 Acc=96.484
# Testing epoch 38: Loss=0.374 Acc=89.860
# Epoch 38: 1284.79s
# Train: 28.63s, Test: 2.71s
#
# Epoch: 39
# Training epoch 39: Loss=0.100 Acc=96.404
# Testing epoch 39: Loss=0.418 Acc=89.000
# Epoch 39: 1316.34s
# Train: 28.83s, Test: 2.72s
#
# Epoch: 40
# Training epoch 40: Loss=0.099 Acc=96.426
# Testing epoch 40: Loss=0.380 Acc=90.220
# Saving..
# Epoch 40: 1348.08s
# Train: 28.76s, Test: 2.98s
#
# Epoch: 41
# Training epoch 41: Loss=0.091 Acc=96.748
# Testing epoch 41: Loss=0.394 Acc=89.640
# Epoch 41: 1379.67s
# Train: 28.78s, Test: 2.80s
#
# Epoch: 42
# Training epoch 42: Loss=0.089 Acc=96.844
# Testing epoch 42: Loss=0.388 Acc=90.050
# Epoch 42: 1410.89s
# Train: 28.46s, Test: 2.77s
#
# Epoch: 43
# Training epoch 43: Loss=0.083 Acc=96.980
# Testing epoch 43: Loss=0.455 Acc=88.970
# Epoch 43: 1442.42s
# Train: 28.79s, Test: 2.74s
#
# Epoch: 44
# Training epoch 44: Loss=0.083 Acc=97.086
# Testing epoch 44: Loss=0.454 Acc=88.810
# Epoch 44: 1473.95s
# Train: 28.75s, Test: 2.78s
#
# Epoch: 45
# Training epoch 45: Loss=0.079 Acc=97.162
# Testing epoch 45: Loss=0.424 Acc=89.310
# Epoch 45: 1505.56s
# Train: 28.82s, Test: 2.78s
#
# Epoch: 46
# Training epoch 46: Loss=0.078 Acc=97.224
# Testing epoch 46: Loss=0.387 Acc=90.320
# Saving..
# Epoch 46: 1537.46s
# Train: 29.14s, Test: 2.77s
#
# Epoch: 47
# Training epoch 47: Loss=0.073 Acc=97.342
# Testing epoch 47: Loss=0.450 Acc=89.580
# Epoch 47: 1569.18s
# Train: 29.23s, Test: 2.49s
#
# Epoch: 48
# Training epoch 48: Loss=0.071 Acc=97.482
# Testing epoch 48: Loss=0.439 Acc=89.570
# Epoch 48: 1601.08s
# Train: 29.47s, Test: 2.43s
#
# Epoch: 49
# Training epoch 49: Loss=0.074 Acc=97.378
# Testing epoch 49: Loss=0.433 Acc=89.690
# Epoch 49: 1632.98s
# Train: 29.39s, Test: 2.51s
#
# Epoch: 50
# Training epoch 50: Loss=0.070 Acc=97.476
# Testing epoch 50: Loss=0.408 Acc=90.270
# Epoch 50: 1664.57s
# Train: 29.13s, Test: 2.46s
#
# Epoch: 51
# Training epoch 51: Loss=0.061 Acc=97.834
# Testing epoch 51: Loss=0.455 Acc=89.750
# Epoch 51: 1696.21s
# Train: 28.90s, Test: 2.74s
#
# Epoch: 52
# Training epoch 52: Loss=0.065 Acc=97.708
# Testing epoch 52: Loss=0.425 Acc=90.090
# Epoch 52: 1727.63s
# Train: 28.72s, Test: 2.71s
#
# Epoch: 53
# Training epoch 53: Loss=0.063 Acc=97.736
# Testing epoch 53: Loss=0.449 Acc=89.650
# Epoch 53: 1758.91s
# Train: 28.48s, Test: 2.80s
#
# Epoch: 54
# Training epoch 54: Loss=0.060 Acc=97.904
# Testing epoch 54: Loss=0.428 Acc=90.060
# Epoch 54: 1790.06s
# Train: 28.46s, Test: 2.68s
#
# Epoch: 55
# Training epoch 55: Loss=0.061 Acc=97.856
# Testing epoch 55: Loss=0.404 Acc=90.680
# Saving..
# Epoch 55: 1821.44s
# Train: 28.48s, Test: 2.89s
#
# Epoch: 56
# Training epoch 56: Loss=0.060 Acc=97.918
# Testing epoch 56: Loss=0.433 Acc=89.950
# Epoch 56: 1852.55s
# Train: 28.43s, Test: 2.68s
#
# Epoch: 57
# Training epoch 57: Loss=0.056 Acc=98.024
# Testing epoch 57: Loss=0.418 Acc=90.630
# Epoch 57: 1884.21s
# Train: 28.84s, Test: 2.82s
#
# Epoch: 58
# Training epoch 58: Loss=0.055 Acc=98.034
# Testing epoch 58: Loss=0.425 Acc=90.630
# Epoch 58: 1915.30s
# Train: 28.31s, Test: 2.79s
#
# Epoch: 59
# Training epoch 59: Loss=0.053 Acc=98.132
# Testing epoch 59: Loss=0.464 Acc=89.770
# Epoch 59: 1946.37s
# Train: 28.29s, Test: 2.77s
#
# Epoch: 60
# Training epoch 60: Loss=0.053 Acc=98.162
# Testing epoch 60: Loss=0.449 Acc=90.080
# Epoch 60: 1978.09s
# Train: 28.61s, Test: 3.12s
#
# Epoch: 61
# Training epoch 61: Loss=0.049 Acc=98.316
# Testing epoch 61: Loss=0.405 Acc=90.900
# Saving..
# Epoch 61: 2009.26s
# Train: 28.40s, Test: 2.77s
#
# Epoch: 62
# Training epoch 62: Loss=0.050 Acc=98.228
# Testing epoch 62: Loss=0.413 Acc=90.600
# Epoch 62: 2040.55s
# Train: 28.68s, Test: 2.61s
#
# Epoch: 63
# Training epoch 63: Loss=0.047 Acc=98.304
# Testing epoch 63: Loss=0.464 Acc=90.030
# Epoch 63: 2072.11s
# Train: 28.69s, Test: 2.88s
#
# Epoch: 64
# Training epoch 64: Loss=0.042 Acc=98.522
# Testing epoch 64: Loss=0.425 Acc=90.670
# Epoch 64: 2103.54s
# Train: 28.60s, Test: 2.83s
#
# Epoch: 65
# Training epoch 65: Loss=0.043 Acc=98.498
# Testing epoch 65: Loss=0.430 Acc=90.780
# Epoch 65: 2134.65s
# Train: 28.28s, Test: 2.84s
#
# Epoch: 66
# Training epoch 66: Loss=0.041 Acc=98.574
# Testing epoch 66: Loss=0.439 Acc=90.340
# Epoch 66: 2165.76s
# Train: 28.42s, Test: 2.69s
#
# Epoch: 67
# Training epoch 67: Loss=0.039 Acc=98.628
# Testing epoch 67: Loss=0.462 Acc=90.250
# Epoch 67: 2196.85s
# Train: 28.32s, Test: 2.76s
#
# Epoch: 68
# Training epoch 68: Loss=0.040 Acc=98.604
# Testing epoch 68: Loss=0.465 Acc=90.820
# Epoch 68: 2228.20s
# Train: 28.70s, Test: 2.65s
#
# Epoch: 69
# Training epoch 69: Loss=0.037 Acc=98.664
# Testing epoch 69: Loss=0.460 Acc=90.530
# Epoch 69: 2259.58s
# Train: 28.56s, Test: 2.82s
#
# Epoch: 70
# Training epoch 70: Loss=0.041 Acc=98.506
# Testing epoch 70: Loss=0.435 Acc=90.950
# Saving..
# Epoch 70: 2291.02s
# Train: 28.67s, Test: 2.77s
#
# Epoch: 71
# Training epoch 71: Loss=0.038 Acc=98.650
# Testing epoch 71: Loss=0.445 Acc=90.740
# Epoch 71: 2321.99s
# Train: 28.35s, Test: 2.62s
#
# Epoch: 72
# Training epoch 72: Loss=0.037 Acc=98.688
# Testing epoch 72: Loss=0.431 Acc=91.240
# Saving..
# Epoch 72: 2353.52s
# Train: 28.72s, Test: 2.82s
#
# Epoch: 73
# Training epoch 73: Loss=0.034 Acc=98.774
# Testing epoch 73: Loss=0.432 Acc=90.890
# Epoch 73: 2385.04s
# Train: 28.79s, Test: 2.73s
#
# Epoch: 74
# Training epoch 74: Loss=0.036 Acc=98.742
# Testing epoch 74: Loss=0.441 Acc=90.860
# Epoch 74: 2415.96s
# Train: 28.26s, Test: 2.66s
#
# Epoch: 75
# Training epoch 75: Loss=0.033 Acc=98.852
# Testing epoch 75: Loss=0.457 Acc=90.910
# Epoch 75: 2447.48s
# Train: 28.78s, Test: 2.75s
#
# Epoch: 76
# Training epoch 76: Loss=0.035 Acc=98.810
# Testing epoch 76: Loss=0.447 Acc=90.970
# Epoch 76: 2478.54s
# Train: 28.36s, Test: 2.70s
#
# Epoch: 77
# Training epoch 77: Loss=0.034 Acc=98.780
# Testing epoch 77: Loss=0.437 Acc=91.160
# Epoch 77: 2510.07s
# Train: 28.96s, Test: 2.57s
#
# Epoch: 78
# Training epoch 78: Loss=0.032 Acc=98.872
# Testing epoch 78: Loss=0.463 Acc=90.760
# Epoch 78: 2542.08s
# Train: 29.22s, Test: 2.79s
#
# Epoch: 79
# Training epoch 79: Loss=0.030 Acc=98.938
# Testing epoch 79: Loss=0.441 Acc=91.220
# Epoch 79: 2573.73s
# Train: 29.25s, Test: 2.40s
#
# Epoch: 80
# Training epoch 80: Loss=0.033 Acc=98.894
# Testing epoch 80: Loss=0.477 Acc=90.710
# Epoch 80: 2605.85s
# Train: 29.71s, Test: 2.41s
#
# Epoch: 81
# Training epoch 81: Loss=0.031 Acc=98.916
# Testing epoch 81: Loss=0.462 Acc=90.920
# Epoch 81: 2638.26s
# Train: 29.87s, Test: 2.54s
#
# Epoch: 82
# Training epoch 82: Loss=0.029 Acc=98.986
# Testing epoch 82: Loss=0.455 Acc=90.990
# Epoch 82: 2670.16s
# Train: 29.37s, Test: 2.53s
#
# Epoch: 83
# Training epoch 83: Loss=0.030 Acc=98.874
# Testing epoch 83: Loss=0.426 Acc=91.340
# Saving..
# Epoch 83: 2701.81s
# Train: 29.02s, Test: 2.64s
#
# Epoch: 84
# Training epoch 84: Loss=0.026 Acc=99.142
# Testing epoch 84: Loss=0.465 Acc=91.070
# Epoch 84: 2733.49s
# Train: 28.92s, Test: 2.75s
#
# Epoch: 85
# Training epoch 85: Loss=0.026 Acc=99.122
# Testing epoch 85: Loss=0.453 Acc=91.240
# Epoch 85: 2764.66s
# Train: 28.48s, Test: 2.70s
#
# Epoch: 86
# Training epoch 86: Loss=0.029 Acc=99.042
# Testing epoch 86: Loss=0.479 Acc=90.660
# Epoch 86: 2795.96s
# Train: 28.56s, Test: 2.73s
#
# Epoch: 87
# Training epoch 87: Loss=0.026 Acc=99.066
# Testing epoch 87: Loss=0.459 Acc=91.240
# Epoch 87: 2827.27s
# Train: 28.67s, Test: 2.64s
#
# Epoch: 88
# Training epoch 88: Loss=0.029 Acc=99.030
# Testing epoch 88: Loss=0.468 Acc=90.840
# Epoch 88: 2858.79s
# Train: 28.74s, Test: 2.77s
#
# Epoch: 89
# Training epoch 89: Loss=0.025 Acc=99.150
# Testing epoch 89: Loss=0.471 Acc=91.270
# Epoch 89: 2889.86s
# Train: 28.29s, Test: 2.78s
#
# Epoch: 90
# Training epoch 90: Loss=0.024 Acc=99.156
# Testing epoch 90: Loss=0.479 Acc=90.970
# Epoch 90: 2920.81s
# Train: 28.33s, Test: 2.62s
#
# Epoch: 91
# Training epoch 91: Loss=0.028 Acc=98.948
# Testing epoch 91: Loss=0.476 Acc=91.000
# Epoch 91: 2951.91s
# Train: 28.34s, Test: 2.76s
#
# Epoch: 92
# Training epoch 92: Loss=0.026 Acc=99.112
# Testing epoch 92: Loss=0.459 Acc=91.100
# Epoch 92: 2982.88s
# Train: 28.19s, Test: 2.77s
#
# Epoch: 93
# Training epoch 93: Loss=0.023 Acc=99.230
# Testing epoch 93: Loss=0.467 Acc=91.250
# Epoch 93: 3014.31s
# Train: 28.70s, Test: 2.74s
#
# Epoch: 94
# Training epoch 94: Loss=0.022 Acc=99.206
# Testing epoch 94: Loss=0.452 Acc=91.420
# Saving..
# Epoch 94: 3045.66s
# Train: 28.50s, Test: 2.85s
#
# Epoch: 95
# Training epoch 95: Loss=0.023 Acc=99.220
# Testing epoch 95: Loss=0.467 Acc=91.220
# Epoch 95: 3076.86s
# Train: 28.39s, Test: 2.81s
#
# Epoch: 96
# Training epoch 96: Loss=0.023 Acc=99.216
# Testing epoch 96: Loss=0.514 Acc=91.000
# Epoch 96: 3107.92s
# Train: 28.39s, Test: 2.67s
#
# Epoch: 97
# Training epoch 97: Loss=0.022 Acc=99.214
# Testing epoch 97: Loss=0.457 Acc=91.570
# Saving..
# Epoch 97: 3139.49s
# Train: 28.75s, Test: 2.82s
#
# Epoch: 98
# Training epoch 98: Loss=0.023 Acc=99.194
# Testing epoch 98: Loss=0.516 Acc=90.820
# Epoch 98: 3170.93s
# Train: 28.71s, Test: 2.73s
#
# Epoch: 99
# Training epoch 99: Loss=0.023 Acc=99.200
# Testing epoch 99: Loss=0.474 Acc=91.170
# Epoch 99: 3202.39s
# Train: 28.76s, Test: 2.70s
#
# Epoch: 100
# Training epoch 100: Loss=0.021 Acc=99.282
# Testing epoch 100: Loss=0.462 Acc=91.190
# Epoch 100: 3233.54s
# Train: 28.45s, Test: 2.69s
#
# Epoch: 101
# Training epoch 101: Loss=0.022 Acc=99.244
# Testing epoch 101: Loss=0.449 Acc=91.730
# Saving..
# Epoch 101: 3264.90s
# Train: 28.65s, Test: 2.71s
#
# Epoch: 102
# Training epoch 102: Loss=0.018 Acc=99.338
# Testing epoch 102: Loss=0.494 Acc=91.330
# Epoch 102: 3295.97s
# Train: 28.33s, Test: 2.74s
#
# Epoch: 103
# Training epoch 103: Loss=0.021 Acc=99.290
# Testing epoch 103: Loss=0.463 Acc=91.610
# Epoch 103: 3326.91s
# Train: 28.28s, Test: 2.66s
#
# Epoch: 104
# Training epoch 104: Loss=0.021 Acc=99.236
# Testing epoch 104: Loss=0.461 Acc=91.340
# Epoch 104: 3358.04s
# Train: 28.40s, Test: 2.73s
#
# Epoch: 105
# Training epoch 105: Loss=0.023 Acc=99.206
# Testing epoch 105: Loss=0.460 Acc=91.490
# Epoch 105: 3389.12s
# Train: 28.46s, Test: 2.62s
#
# Epoch: 106
# Training epoch 106: Loss=0.020 Acc=99.300
# Testing epoch 106: Loss=0.454 Acc=91.750
# Saving..
# Epoch 106: 3420.26s
# Train: 28.41s, Test: 2.72s
#
# Epoch: 107
# Training epoch 107: Loss=0.019 Acc=99.362
# Testing epoch 107: Loss=0.466 Acc=91.360
# Epoch 107: 3451.41s
# Train: 28.39s, Test: 2.75s
#
# Epoch: 108
# Training epoch 108: Loss=0.017 Acc=99.400
# Testing epoch 108: Loss=0.473 Acc=91.700
# Epoch 108: 3482.91s
# Train: 28.72s, Test: 2.78s
#
# Epoch: 109
# Training epoch 109: Loss=0.020 Acc=99.346
# Testing epoch 109: Loss=0.474 Acc=91.380
# Epoch 109: 3514.01s
# Train: 28.33s, Test: 2.77s
#
# Epoch: 110
# Training epoch 110: Loss=0.016 Acc=99.460
# Testing epoch 110: Loss=0.469 Acc=91.810
# Saving..
# Epoch 110: 3545.66s
# Train: 28.90s, Test: 2.76s
#
# Epoch: 111
# Training epoch 111: Loss=0.016 Acc=99.460
# Testing epoch 111: Loss=0.476 Acc=91.610
# Epoch 111: 3577.35s
# Train: 29.12s, Test: 2.57s
#
# Epoch: 112
# Training epoch 112: Loss=0.018 Acc=99.382
# Testing epoch 112: Loss=0.513 Acc=91.170
# Epoch 112: 3609.11s
# Train: 29.26s, Test: 2.50s
#
# Epoch: 113
# Training epoch 113: Loss=0.020 Acc=99.314
# Testing epoch 113: Loss=0.480 Acc=91.090
# Epoch 113: 3641.00s
# Train: 29.36s, Test: 2.53s
#
# Epoch: 114
# Training epoch 114: Loss=0.017 Acc=99.412
# Testing epoch 114: Loss=0.462 Acc=91.460
# Epoch 114: 3672.51s
# Train: 29.01s, Test: 2.50s
#
# Epoch: 115
# Training epoch 115: Loss=0.016 Acc=99.452
# Testing epoch 115: Loss=0.483 Acc=91.420
# Epoch 115: 3703.99s
# Train: 28.79s, Test: 2.69s
#
# Epoch: 116
# Training epoch 116: Loss=0.017 Acc=99.400
# Testing epoch 116: Loss=0.445 Acc=91.770
# Epoch 116: 3735.54s
# Train: 28.85s, Test: 2.70s
#
# Epoch: 117
# Training epoch 117: Loss=0.016 Acc=99.466
# Testing epoch 117: Loss=0.492 Acc=91.420
# Epoch 117: 3753.17s
# Train: 16.04s, Test: 1.59s
#
# Epoch: 118
# Training epoch 118: Loss=0.016 Acc=99.478
# Testing epoch 118: Loss=0.504 Acc=91.380
# Epoch 118: 3769.40s
# Train: 14.64s, Test: 1.59s
#
# Epoch: 119
# Training epoch 119: Loss=0.016 Acc=99.454
# Testing epoch 119: Loss=0.469 Acc=91.760
# Epoch 119: 3785.72s
# Train: 14.68s, Test: 1.64s

# %%
plt.plot(range(120),train_acc_history,'-',linewidth=3,label='Train accuracy')
plt.plot(range(120),test_acc_history,'-',linewidth=3,label='Test accuracy')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
